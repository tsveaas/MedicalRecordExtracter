# %%
# Load in libraries
import pandas as pd
import re
from fuzzywuzzy import fuzz
import numpy as np

# %% [markdown]
# # Units and Parameter names

# %%
params_json = pd.read_json('X1.json')
params_json
# Out:
#     Abbreviation                                           Synonyms
# 0        11DEOXY  [11 deoxycortisol, Cortodoxin, Deoxycorticoste...
# 1          17OHP  [17 hydroxyprogesterone, 17-Hydroxyprogesteron...
# 2          ACACT  [acetoacetate, AcAc, Acetoacetic Acid, Diaceti...
# 3            ALT  [alanine transaminase, SGPT, Serum Glutamate P...
# 4            ALB  [albumin, Serum Albumin, Human Albumin, Plasma...
# ..           ...                                                ...
# 254          PDW  [Platelet Distribution Width, Platelet Width, ...
# 255        TFT-R  [Thyroid Function Test - Reflex, Thyroid Funct...
# 256          TFT  [Thyroid Function Test, Thyroid Function Panel...
# 257        TPOAb  [Thyroid Peroxidase Antibodies, Anti-Thyroid P...
# 258         TgAb  [Thyroglobulin Antibodies, Anti-Thyroglobulin ...
#
# [259 rows x 2 columns]

# %%
params_json['Abbreviation'].value_counts()
# Out:
# Abbreviation
# CA2729    2
# CO2       2
# CRPLN     2
# CEA       2
# CCTN      2
#          ..
# GLOB      1
# GLCGN     1
# GLUC      1
# G6PD      1
# TgAb      1
# Name: count, Length: 249, dtype: int64

# %%
# Check the duplicate abbreviations
params_json['Synonyms'][params_json['Abbreviation'] == 'CO2'][46]
# Out:
# ['carbon dioxide',
#  'CO2 Gas',
#  'Carbonic Acid Gas',
#  'Carbon Dioxide Molecule',
#  'CO2 Gas',
#  'Carbonic Acid Anhydride',
#  'Dry Ice',
#  'CO2',
#  'Carbonic Anhydride',
#  'Carbon(IV) Oxide']

# %%
params_json['Synonyms'][params_json['Abbreviation'] == 'CO2'][56]
# Out:
# ['carbon dioxide',
#  'CO2 Gas',
#  'Carbonic Acid Gas',
#  'Respired Carbon Dioxide',
#  'Bicarbonate']

# %%
# Group the synonyms of the parameters that appear more than once.
params_json = params_json.groupby('Abbreviation')['Synonyms'].agg(lambda x: sum(x, [])).reset_index()

# %%
# Add the abbreviation to the synonyms row
params_json['Synonyms'] = params_json.apply(lambda row: [row['Abbreviation']] + row['Synonyms'], axis =1)

# %%
params_json
# Out:
#     Abbreviation                                           Synonyms
# 0        11DEOXY  [11DEOXY, 11 deoxycortisol, Cortodoxin, Deoxyc...
# 1          17OHP  [17OHP, 17 hydroxyprogesterone, 17-Hydroxyprog...
# 2      A/G_RATIO  [A/G_RATIO, Albumin/Globulin Ratio, A/G Ratio,...
# 3          A1GLO  [A1GLO, alpha-1 globulin, Alpha-1 Globulin, α1...
# 4          A2GLO  [A2GLO, alpha-2 globulin, Alpha-2 Globulin, α2...
# ..           ...                                                ...
# 244        vitB9  [vitB9, Vitamin B9, Folate, Folic Acid, Folaci...
# 245         vitC  [vitC, Vitamin C, Ascorbic Acid, Ascorbate, L-...
# 246         vitD  [vitD, Vitamin D, Calciferol, Cholecalciferol,...
# 247         vitE  [vitE, Vitamin E, Tocopherol, Tocotrienol, Alp...
# 248        vitK1  [vitK1, Vitamin K1, Phylloquinone, Phytomenadi...
#
# [249 rows x 2 columns]

# %% [markdown]
# # Analyse samples

# %%
# Create list of samples given
sample_list = ['0ab9800e-bc9a-4388-aaa2-d4fc05e7d111.txt',
               '0b8706dc-c9af-4c6b-887d-2f85b5a511e7.txt',
               '0c59298d-4205-4f6a-8bc9-c078123da03a.txt',
               '0c848136-de54-49eb-a3c4-b04dda11ef42.txt',
               '0ca602c0-d93a-4ae2-b91f-532db7e174ae.txt',
               '0deee5f5-f9d3-4712-8d2e-c5f7cd9895dc.txt',
               '0ea75106-2a9d-4adc-9dad-33256e7d9aad.txt',
               '0ecb52fd-138f-4566-bdef-06fabdd7019d.txt',
               '02b832e1-66cc-4f35-8b52-abf41cd821b2.txt']

# %%
dates = ['10/12/2018',
         '13/02/2024',
         '18/01/2024',
         'missing',
         '18/01/2024',
         '02/04/2019',
         '26/94/2019',
         '02/02/2024',
         '03/03/2022'
         ]

# %%
samples = pd.DataFrame()

# %%
# Save each sample to a different variable
raw_text_list = []
for sample in sample_list:
        with open(sample, 'r', encoding='latin1') as f:
            raw_text_list.append(f.read())

# %%
samples['raw_text'] = raw_text_list

# %%
samples['date'] = dates

# %%
samples
# Out:
#                                             raw_text        date
# 0  Patient Name;, \nPatient Address: \n\nD.O.B: 2...  10/12/2018
# 1  Patient Health Summary\n\nremoved\n\nremoved\n...  13/02/2024
# 2  iilaverty -â- Pathology Report resuits @RCPA...  18/01/2024
# 3   \n\nHAEMATOLOGY\n\n \n15\nBLOOD - EDTA Result...     missing
# 4  ilaverty Pathology Report resus\n\npathology E...  18/01/2024
# 5  AUSTRALIAN LABORATORY 3427-18703 Referred: 02/...  02/04/2019
# 6  \n\n \n\n \n\n  \n \n  \n \n \n \n \n\n29 APR\...  26/94/2019
# 7  Peghy Â«Ao Â¢4 AG +48 | 38 â> CLINICAL LABOR...  02/02/2024
# 8  Patient Name ee Barcode ; [eennnennninittte\n\...  03/03/2022

# %% [markdown]
# # Building Function

# %%
sample_1_list = samples['raw_text'][1].split('\n')
sample_1_list
# Out:
# ['Patient Health Summary',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  '',
#  'D.O.B.: ',
#  '',
#  'Record No.:',
#  '',
#  'Home Phone:',
#  '',
#  'Work Phone:',
#  '',
#  'removed',
#  '',
#  'Printed on 27th February 2024',
#  '',
#  ' ',
#  '',
#  'Investigations:',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Name of Test: MSU',
#  'Requested: 30/01/2024 Collected: 30/01/2024 Reported: 13/02/2024 17:17',
#  '',
#  'Clinical notes: 2? UTI',
#  '',
#  'Clinical Notes : ? UTI',
#  '',
#  'Urine',
#  '',
#  'pH 7 Protein Nil Glucose Nil',
#  '',
#  'Blood Nil Ketones Nil',
#  '',
#  'Specific gravity 1.012 (1.005 - 1.030)',
#  '',
#  'Microscopy',
#  '',
#  'Leucocytes 5 x10*6/L ( <10 )',
#  'Erythrocytes H 14 x10*6/L ( <10 )',
#  'Epithelial cells 5 x10*6/L',
#  '',
#  'Growth of bowel/perineal flora',
#  'Comment on Lab ID 887475034',
#  '',
#  'UTI is unlikely without a high white cell count in urine.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: MSU',
#  'Tests Pending',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  '',
#  'Name of Test: Rubella IgG, IgM',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  '',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Rubella Serology',
#  'Rubella IgG (CMIA) 11 IU/mL',
#  '',
#  'Comment on Lab ID 838828312',
#  '',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  '',
#  'Antibody detected. In an asymptomatic individual this result is consistent',
#  'with past infection or vaccination and correlates with protective',
#  'immunity.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Biochemistry',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'BIOCHEMISTRY',
#  '',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  '',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Sodium 140 L 134 139 140 mmol/L (135-145)',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L (3.5-5.5)',
#  'Chloride 106 106 107 106 mmol/L (95-110)',
#  'Bicarbonate 23 21 21 25 mmol/L (20-32)',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L (2.5-7.0)',
#  'Creatinine 70 70 65 65 umol/L (45-85)',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 (>59)',
#  'Calcium 2.40 mmol/L (2.15-2.55)',
#  'Corr Calcium 2.34 mmol/L (2.15-2.55)',
#  'Magnesium. 0.84 mmol/L (0.65-1.00)',
#  'Phosphate. 1.08 mmol/L (0.8-1.5)',
#  '',
#  'removed',
#  '\x0c',
#  'Bili.Total 11 H 20 H 18 umol/L (3-15)',
#  '',
#  'ALP 59 60 70 U/L (20-105)',
#  'GGT 13 11 15 U/L (5-35)',
#  '',
#  'LD 187 203 178 U/L (120-250)',
#  'AST 19 25 23 U/L (10-35)',
#  'ALT 16 12 22 U/L (5-30)',
#  'Total Protein 76 70 72 g/L (68-85)',
#  'Albumin 46 44 46 g/L (37-48)',
#  'Globulin 30 26 26 g/L (23-39)',
#  'Cholesterol 4.7 mmol/L (<5.5)',
#  'Triglycerides 0.6 mmol/L (<2.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'eGFR (mL/min/1.73m2) calculated by CKD-EPI formula - see www.kidney.org.au',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: _ Glucose',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'GLUCOSE',
#  '',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L (3.6-6.0)',
#  'R Gluc Plasma 4.5 mmol/L (3.6-7.8)',
#  'F Gluc Serum 4.8 mmol/L (3.6-6.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'an OGTT could be indicated in the presence of risk factors such as',
#  'metabolic syndrome, past gestational diabetes, polycystic ovary or family',
#  'history of type 2 diabetes.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  'removed',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Iron Studies',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'IRON',
#  '',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L (5.0-30.0)',
#  'Transferrin 2.2 2.5 2.7 g/L (2.0-3.6)',
#  'TIBC (Calc) 50 56 60 umol/L (46-77)',
#  'Saturation 23 22 42 % (10-45)',
#  'Ferritin 38 719 39 47 ug/L (15-200)',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Lipids HDL(s)',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 23/12/17 31/01/24',
#  '',
#  'Time F-Fast 0825 F 0727 F',
#  '',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Cholesterol L 3.8 4.7 mmol/L (<5.5)',
#  'Triglycerides 0.5 0.6 mmol/L (<2.0)',
#  'HDL Chol. 1.6 2.0 mmol/L (>1.2)',
#  'LDL Chol. 2.0 2.4 mmol/L (<3.0)',
#  'Non-HDL Chol. a | mmol/L (<4.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Please note that the above reference limits are decision limits.',
#  '',
#  'A flag based on these limits is an indication to review the absolute',
#  'cardiovascular risk for the patient. For assessment of absolute',
#  'cardiovascular disease risk please see www.cvdcheck.org.au',
#  '',
#  'removed',
#  '\x0c',
#  'The above decision limits are based on the European Atherosclerosis Society',
#  '(EAS) and European Federation of Clinical Chemistry and Laboratory Medicine',
#  '(EFLM) Consensus Statement 2016 and the Australasian Association of',
#  'Clinical Biochemistry and Laboratory Medicine (AACB) Lipid Reporting',
#  'Guideline 2018.',
#  '',
#  'Lipid treatment targets for patients at high risk of cardiovascular',
#  'disease:',
#  '',
#  'Total cholesterol <4.0 mmol/L',
#  '',
#  'Triglyceride <2.0 mmol/L',
#  '',
#  'HDL cholesterol >1.0 mmol/L',
#  '',
#  'LDL cholesterol <2.5 mmol/L (<1.8 mmol/L for very high risk)',
#  'Non-HDL cholesterol <3.3 mmol/L (<2.5 mmol/L for very high risk)',
#  'High risk - Primary prevention Very high risk - Secondary prevention',
#  '',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  '',
#  'Please note that as there is a continuum of risk, benefits are obtained for',
#  'any measured lipid components moving towards and beyond the various target',
#  'levels.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Haematology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'HAEMATOLOGY',
#  '',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  '',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L (119-160)',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L (3.8-5.8)',
#  'Haematocrit 0.38 0.38 0.37 0.41 (0.35-0.48)',
#  'MCV 90 88 87 92 Â£L (80-100)',
#  'MCH 29.6 29.8 30.0 29.9 pg (27.0-32.0)',
#  'MCHC 328 338 344 325 g/L (310-360)',
#  'RDW 11.9 11.9 12.4 13.0 (10.0-15.0)',
#  'wcc 7.7 8.4 9.3 7.9 x10*9/L (4.0-11.0)',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L (2.0-7.5)',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L (1.0-4.0)',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L (0.0-1.0)',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L (0.0-0.5)',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L (0.0-0.3)',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC (<1)',
#  '',
#  'removed',
#  '\x0c',
#  'Platelets 221 267 234 261 x10*9/L (150-450)',
#  'ESR 1 mm/h (1-22)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Full blood count is within reference limits',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Hep B Serology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Hepatitis B Serology',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  '',
#  'Hepatitis B - Immune (>/=10 IU/L).',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Thyroid Function',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'TET',
#  '',
#  'removed',
#  '\x0c',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 milU/L (0.40-3.50)',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Vit D(s)',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0839 F 0727 F',
#  '',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L (50-140)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  "According to the Position Statement 'Vitamin D and health in adults in",
#  "Australia and New Zealand' MJA, 196(11):686-687, 2012, Vitamin D status is",
#  'defined as:',
#  '',
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  '',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'summer, to allow for seasonal decrease.',
#  '',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'to patients at risk of Vitamin D deficiency such as chronic lack of sun',
#  'exposure.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'removed',
#  '\x0c',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  'Copy to:',
#  'removed',
#  '',
#  'Name of Test: Haematology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 11:47',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'HAEMATOLOGY',
#  '',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  '',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L (119-160)',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L (3.8-5.8)',
#  'Haematocrit 0.38 0.38 0.37 0.41 (0.35-0.48)',
#  'MCV 90 88 87 92 fL (80-100)',
#  'MCH 29.6 29.8 30.0 29.9 pg (27.0-32.0)',
#  'MCHC 328 338 344 325 g/L (310-360)',
#  'RDW 11.9 11.9 12.4 13.0 (10.0-15.0)',
#  'WCC 7.7 8.4 9.3 7.9 x10*9/L (4.0-11.0)',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L (2.0-7.5)',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L (1.0-4.0)',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L (0.0-1.0)',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L (0.0-0.5)',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L (0.0-0.3)',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC (<1)',
#  'Platelets 221 267 234 261 x10*9/L (150-450)',
#  'ESR 1 mm/h (1-22)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Full blood count is within reference limits',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: FBC (e)',
#  '',
#  'Tests Pending : LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, RubG(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Biochemistry',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'BIOCHEMISTRY',
#  '',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  '',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  '',
#  'removed',
#  '\x0c',
#  'Status Fasting Fasting',
#  '',
#  'Sodium 140 L 134 139 140 mmol/L (135-145)',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L (3.5-5.5)',
#  'Chloride 106 106 107 106 mmol/L (95-110)',
#  'Bicarbonate 23 21 21 25 mmol/L (20-32)',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L (2.5-7.0)',
#  'Creatinine 70 70 65 65 umol/L (45-85)',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 (>59)',
#  'Calcium 2.40 mmol/L (2.15-2.55)',
#  'Corr Calcium 2.34 mmol/L (2.15-2.55)',
#  'Magnesium. 0.84 mmol/L (0.65-1.00)',
#  'Phosphate. 1.08 mmol/L (0.8-1.5)',
#  'Bili.Total 11 H 20 H 18 umol/L (3-15)',
#  '',
#  'ALP 59 60 70 U/L (20-105)',
#  'GGT 13 11 15 U/L (5-35)',
#  '',
#  'LD 187 203 178 U/L (120-250)',
#  'AST 19 25 23 U/L (10-35)',
#  '',
#  'ALT 16 12 22 U/L (5-30)',
#  'Total Protein 76 70 72 g/L (68-85)',
#  'Albumin 46 44 46 g/L (37-48)',
#  'Globulin 30 26 26 g/L (23-39)',
#  'Cholesterol 4.7 mmol/L (<5.5)',
#  'Triglycerides 0.6 mmol/L (<2.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'eGFR (mL/min/1.73m2) calculated by CKD-EPI formula - see www.kidney.org.au',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),FBC(e)',
#  '',
#  'Tests Pending : Iron(s),Vit D(s),TSH(s),HBSAb(s),HB-Sero, RubG(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: _Glucose',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'GLUCOSE',
#  '',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L (3.6-6.0)',
#  'R Gluc Plasma 4.5 mmol/L (3.6-7.8)',
#  'F Gluc Serum 4.8 mmol/L (3.6-6.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'an OGTT could be indicated in the presence of risk factors such as',
#  'metabolic syndrome, past gestational diabetes, polycystic ovary or family',
#  'history of type 2 diabetes.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'removed',
#  '\x0c',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),FBC(e)',
#  '',
#  'Tests Pending : Iron(s),Vit D(s),TSH(s),HBSAb(s),HB-Sero, RubG(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Lipids HDL(s)',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 23/12/17 31/01/24',
#  '',
#  'Time F-Fast 0825 F 0727 F',
#  '',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Cholesterol L 3.8 4.7 mmol/L (<5.5)',
#  'Triglycerides 0.5 0.6 mmol/L (<2.0)',
#  'HDL Chol. 1.6 2.0 mmol/L (>1.2)',
#  'LDL Chol. 2.0 2.4 mmol/L (<3.0)',
#  'Non-HDL Chol. 2.7 mmol/L (<4.0)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Please note that the above reference limits are decision limits.',
#  '',
#  'A flag based on these limits is an indication to review the absolute',
#  'cardiovascular risk for the patient. For assessment of absolute',
#  'cardiovascular disease risk please see www.cvdcheck.org.au',
#  '',
#  'The above decision limits are based on the European Atherosclerosis Society',
#  '(EAS) and European Federation of Clinical Chemistry and Laboratory Medicine',
#  '(EFLM) Consensus Statement 2016 and the Australasian Association of',
#  'Clinical Biochemistry and Laboratory Medicine (AACB) Lipid Reporting',
#  'Guideline 2018.',
#  '',
#  'Lipid treatment targets for patients at high risk of cardiovascular',
#  'disease:',
#  '',
#  'Total cholesterol <4.0 mmol/L',
#  '',
#  'Triglyceride <2.0 mmol/L',
#  '',
#  'HDL cholesterol >1.0 mmol/L',
#  '',
#  'LDL cholesterol <2.5 mmol/L (<1.8 mmol/L for very high risk)',
#  'Non-HDL cholesterol <3.3 mmol/L (<2.5 mmol/L for very high risk)',
#  'High risk - Primary prevention Very high risk - Secondary prevention',
#  '',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  '',
#  'Please note that as there is a continuum of risk, benefits are obtained for',
#  'any measured lipid components moving towards and beyond the various target',
#  'levels.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),FBC(e)',
#  '',
#  'Tests Pending : Iron(s),Vit D(s),TSH(s),HBSAb(s),HB-Sero, RubG(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  'removed',
#  'removed',
#  'remoed',
#  'Laboratory: dhm',
#  'removed',
#  'Copy to:',
#  'removed',
#  '',
#  'Name of Test: Hep B Serology',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  '',
#  'Clinical notes: pregnancy planning',
#  '',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Hepatitis B Serology',
#  '',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  '',
#  'Hepatitis B - Immune (>/=10 IU/L).',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),TSH(s),HBsAb(s),HB-Sero,',
#  'FBC (e) , RubG (s)',
#  '',
#  'Tests Pending : Vit D(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Rubella IgG, IgM',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Rubella Serology',
#  'Rubella IgG (CMIA) 11 IU/mL',
#  '',
#  'Comment on Lab ID 838828312',
#  '',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  '',
#  'Antibody detected. In an asymptomatic individual this result is consistent',
#  'with past infection or vaccination and correlates with protective',
#  'immunity.',
#  '',
#  'removed',
#  '\x0c',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),TSH(s),HBsAb(s),HB-Sero,',
#  'FBC (e) , RubG (s)',
#  '',
#  'Tests Pending : Vit D(s)',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Vit D(s)',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 05:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0839 F 0727 F',
#  '',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L (50-140)',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  "According to the Position Statement 'Vitamin D and health in adults in",
#  "Australia and New Zealand' MJA, 196(11):686-687, 2012, Vitamin D status is",
#  'defined as:',
#  '',
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  '',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'summer, to allow for seasonal decrease.',
#  '',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'to patients at risk of Vitamin D deficiency such as chronic lack of sun',
#  'exposure.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT(s),C(s),UCreat(s),E(s),Glu(s),Phos(s),Iron(s),',
#  'Lipids HDL(s),Ca(s),Mg(s),Vit D(s),TSH(s),HBsAb(s),',
#  'HB-Sero, FBC (e) ,RubG(s)',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Iron Studies',
#  '',
#  'removed',
#  '\x0c',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  '',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'IRON',
#  '',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  ...]

# %%
def contains_number(string):
    # Check if the string contains a number
    return bool(re.search(r'\d', string))

def contains_date(string):
    # Check if the string contains a date
    return bool(re.search(r'\b\d{2}/\d{2}/\d{4}\b', string))

def remove_parentheses(line):
    # Define a regular expression pattern to match parentheses and their contents
    pattern = r'\([^()]*\)|\[[^\[\]]*\]'

    # Apply the pattern to each line and remove the matched substrings
    cleaned_line = re.sub(pattern, '', line)

    return cleaned_line

# %%
# Filter the list to keep only strings that contain a number
filtered_list = list(map(lambda x: remove_parentheses(x), sample_1_list))

filtered_list
# Out:
# ['Patient Health Summary',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  '',
#  'D.O.B.: ',
#  '',
#  'Record No.:',
#  '',
#  'Home Phone:',
#  '',
#  'Work Phone:',
#  '',
#  'removed',
#  '',
#  'Printed on 27th February 2024',
#  '',
#  ' ',
#  '',
#  'Investigations:',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Name of Test: MSU',
#  'Requested: 30/01/2024 Collected: 30/01/2024 Reported: 13/02/2024 17:17',
#  '',
#  'Clinical notes: 2? UTI',
#  '',
#  'Clinical Notes : ? UTI',
#  '',
#  'Urine',
#  '',
#  'pH 7 Protein Nil Glucose Nil',
#  '',
#  'Blood Nil Ketones Nil',
#  '',
#  'Specific gravity 1.012 ',
#  '',
#  'Microscopy',
#  '',
#  'Leucocytes 5 x10*6/L ',
#  'Erythrocytes H 14 x10*6/L ',
#  'Epithelial cells 5 x10*6/L',
#  '',
#  'Growth of bowel/perineal flora',
#  'Comment on Lab ID 887475034',
#  '',
#  'UTI is unlikely without a high white cell count in urine.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: MSU',
#  'Tests Pending',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  '',
#  'Name of Test: Rubella IgG, IgM',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  '',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Rubella Serology',
#  'Rubella IgG  11 IU/mL',
#  '',
#  'Comment on Lab ID 838828312',
#  '',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  '',
#  'Antibody detected. In an asymptomatic individual this result is consistent',
#  'with past infection or vaccination and correlates with protective',
#  'immunity.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Biochemistry',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'BIOCHEMISTRY',
#  '',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  '',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  '',
#  'removed',
#  '\x0c',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  '',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  '',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'eGFR  calculated by CKD-EPI formula - see www.kidney.org.au',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: _ Glucose',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'GLUCOSE',
#  '',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'an OGTT could be indicated in the presence of risk factors such as',
#  'metabolic syndrome, past gestational diabetes, polycystic ovary or family',
#  'history of type 2 diabetes.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  'removed',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Iron Studies',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'IRON',
#  '',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L ',
#  'Transferrin 2.2 2.5 2.7 g/L ',
#  'TIBC  50 56 60 umol/L ',
#  'Saturation 23 22 42 % ',
#  'Ferritin 38 719 39 47 ug/L ',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Lipids HDL',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 23/12/17 31/01/24',
#  '',
#  'Time F-Fast 0825 F 0727 F',
#  '',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Non-HDL Chol. a | mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Please note that the above reference limits are decision limits.',
#  '',
#  'A flag based on these limits is an indication to review the absolute',
#  'cardiovascular risk for the patient. For assessment of absolute',
#  'cardiovascular disease risk please see www.cvdcheck.org.au',
#  '',
#  'removed',
#  '\x0c',
#  'The above decision limits are based on the European Atherosclerosis Society',
#  ' and European Federation of Clinical Chemistry and Laboratory Medicine',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Clinical Biochemistry and Laboratory Medicine  Lipid Reporting',
#  'Guideline 2018.',
#  '',
#  'Lipid treatment targets for patients at high risk of cardiovascular',
#  'disease:',
#  '',
#  'Total cholesterol <4.0 mmol/L',
#  '',
#  'Triglyceride <2.0 mmol/L',
#  '',
#  'HDL cholesterol >1.0 mmol/L',
#  '',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'High risk - Primary prevention Very high risk - Secondary prevention',
#  '',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  '',
#  'Please note that as there is a continuum of risk, benefits are obtained for',
#  'any measured lipid components moving towards and beyond the various target',
#  'levels.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Haematology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'HAEMATOLOGY',
#  '',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  '',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 Â£L ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'wcc 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  '',
#  'removed',
#  '\x0c',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Full blood count is within reference limits',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Hep B Serology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Hepatitis B Serology',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  '',
#  'Hepatitis B - Immune .',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Thyroid Function',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'TET',
#  '',
#  'removed',
#  '\x0c',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 milU/L ',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Vit D',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0839 F 0727 F',
#  '',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  "According to the Position Statement 'Vitamin D and health in adults in",
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'defined as:',
#  '',
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  '',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'summer, to allow for seasonal decrease.',
#  '',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'to patients at risk of Vitamin D deficiency such as chronic lack of sun',
#  'exposure.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'removed',
#  '\x0c',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  'Copy to:',
#  'removed',
#  '',
#  'Name of Test: Haematology',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 11:47',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'HAEMATOLOGY',
#  '',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  '',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 fL ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'WCC 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Full blood count is within reference limits',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: FBC ',
#  '',
#  'Tests Pending : LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, RubG',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Biochemistry',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'BIOCHEMISTRY',
#  '',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  '',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  '',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  '',
#  'removed',
#  '\x0c',
#  'Status Fasting Fasting',
#  '',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  '',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  '',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  '',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  'eGFR  calculated by CKD-EPI formula - see www.kidney.org.au',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,',
#  'Lipids HDL,Ca,Mg,FBC',
#  '',
#  'Tests Pending : Iron,Vit D,TSH,HBSAb,HB-Sero, RubG',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: _Glucose',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'GLUCOSE',
#  '',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  '',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'an OGTT could be indicated in the presence of risk factors such as',
#  'metabolic syndrome, past gestational diabetes, polycystic ovary or family',
#  'history of type 2 diabetes.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'removed',
#  '\x0c',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,',
#  'Lipids HDL,Ca,Mg,FBC',
#  '',
#  'Tests Pending : Iron,Vit D,TSH,HBSAb,HB-Sero, RubG',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Lipids HDL',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 23/12/17 31/01/24',
#  '',
#  'Time F-Fast 0825 F 0727 F',
#  '',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Status Fasting Fasting',
#  '',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Non-HDL Chol. 2.7 mmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  'Please note that the above reference limits are decision limits.',
#  '',
#  'A flag based on these limits is an indication to review the absolute',
#  'cardiovascular risk for the patient. For assessment of absolute',
#  'cardiovascular disease risk please see www.cvdcheck.org.au',
#  '',
#  'The above decision limits are based on the European Atherosclerosis Society',
#  ' and European Federation of Clinical Chemistry and Laboratory Medicine',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Clinical Biochemistry and Laboratory Medicine  Lipid Reporting',
#  'Guideline 2018.',
#  '',
#  'Lipid treatment targets for patients at high risk of cardiovascular',
#  'disease:',
#  '',
#  'Total cholesterol <4.0 mmol/L',
#  '',
#  'Triglyceride <2.0 mmol/L',
#  '',
#  'HDL cholesterol >1.0 mmol/L',
#  '',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'High risk - Primary prevention Very high risk - Secondary prevention',
#  '',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  '',
#  'Please note that as there is a continuum of risk, benefits are obtained for',
#  'any measured lipid components moving towards and beyond the various target',
#  'levels.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,',
#  'Lipids HDL,Ca,Mg,FBC',
#  '',
#  'Tests Pending : Iron,Vit D,TSH,HBSAb,HB-Sero, RubG',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '\x0c',
#  'removed',
#  'removed',
#  'removed',
#  'remoed',
#  'Laboratory: dhm',
#  'removed',
#  'Copy to:',
#  'removed',
#  '',
#  'Name of Test: Hep B Serology',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  '',
#  'Clinical notes: pregnancy planning',
#  '',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Hepatitis B Serology',
#  '',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  '',
#  'Hepatitis B - Immune .',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,TSH,HBsAb,HB-Sero,',
#  'FBC  , RubG ',
#  '',
#  'Tests Pending : Vit D',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Rubella IgG, IgM',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Rubella Serology',
#  'Rubella IgG  11 IU/mL',
#  '',
#  'Comment on Lab ID 838828312',
#  '',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  '',
#  'Antibody detected. In an asymptomatic individual this result is consistent',
#  'with past infection or vaccination and correlates with protective',
#  'immunity.',
#  '',
#  'removed',
#  '\x0c',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,TSH,HBsAb,HB-Sero,',
#  'FBC  , RubG ',
#  '',
#  'Tests Pending : Vit D',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  'Your Reference: Lab Reference: removed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Vit D',
#  '',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 05:17',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'Date 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0839 F 0727 F',
#  '',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  '',
#  'Comments on Collection 31/01/24 0727 F:',
#  '',
#  "According to the Position Statement 'Vitamin D and health in adults in",
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'defined as:',
#  '',
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  '',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'summer, to allow for seasonal decrease.',
#  '',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'to patients at risk of Vitamin D deficiency such as chronic lack of sun',
#  'exposure.',
#  '',
#  'NATA Accreditation No 2178',
#  '',
#  'Tests Completed: LFT,C,UCreat,E,Glu,Phos,Iron,',
#  'Lipids HDL,Ca,Mg,Vit D,TSH,HBsAb,',
#  'HB-Sero, FBC  ,RubG',
#  '',
#  'Tests Pending',
#  '',
#  'Sample Pending',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'removed',
#  '',
#  'remoed',
#  '',
#  'Laboratory: dhm',
#  '',
#  'removed',
#  '',
#  'Copy to:',
#  '',
#  'removed',
#  '',
#  'Name of Test: Iron Studies',
#  '',
#  'removed',
#  '\x0c',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  '',
#  'Clinical notes: pregnancy planning',
#  'Clinical Notes : pregnancy planning',
#  '',
#  'IRON',
#  '',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  '',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  ...]

# %%
# Filter the list to keep only strings that contain a number
filtered_list = [s for s in filtered_list if contains_number(s)]

filtered_list
# Out:
# ['Printed on 27th February 2024',
#  'Requested: 30/01/2024 Collected: 30/01/2024 Reported: 13/02/2024 17:17',
#  'Clinical notes: 2? UTI',
#  'pH 7 Protein Nil Glucose Nil',
#  'Specific gravity 1.012 ',
#  'Leucocytes 5 x10*6/L ',
#  'Erythrocytes H 14 x10*6/L ',
#  'Epithelial cells 5 x10*6/L',
#  'Comment on Lab ID 887475034',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Rubella IgG  11 IU/mL',
#  'Comment on Lab ID 838828312',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'history of type 2 diabetes.',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L ',
#  'Transferrin 2.2 2.5 2.7 g/L ',
#  'TIBC  50 56 60 umol/L ',
#  'Saturation 23 22 42 % ',
#  'Ferritin 38 719 39 47 ug/L ',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 23/12/17 31/01/24',
#  'Time F-Fast 0825 F 0727 F',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 Â£L ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'wcc 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 milU/L ',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 13/02/2024 17:17',
#  'Date 28/07/23 31/01/24',
#  'Time F-Fast 0839 F 0727 F',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 11:47',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 fL ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'WCC 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'history of type 2 diabetes.',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 31/01/2024 12:17',
#  'Date 23/12/17 31/01/24',
#  'Time F-Fast 0825 F 0727 F',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Non-HDL Chol. 2.7 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Rubella IgG  11 IU/mL',
#  'Comment on Lab ID 838828312',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 05:17',
#  'Date 28/07/23 31/01/24',
#  'Time F-Fast 0839 F 0727 F',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L ',
#  'Transferrin 2.2 2.5 2.7 g/L ',
#  'TIBC  50 56 60 umol/L ',
#  'Saturation 23 22 42 % ',
#  'Ferritin 38 79 39 47 ug/L ',
#  'NATA Accreditation No 2178',
#  'Requested: 30/01/2024 Collected: 31/01/2024 Reported: 01/02/2024 02:47',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 mIU/L ',
#  'NATA Accreditation No 2178',
#  'Requested: 02/02/2024 Collected: 02/02/2024 Reported: 13/02/2024 17:17',
#  'Date 29/01/19 02/02/24',
#  'Time 1640 1429',
#  'Lab ID 295348768 839050249 Units Reference',
#  'BhcG  <5 <5 IU/L',
#  'Comments on Collection 02/02/24 1429:',
#  '4 weeks 16 - 160',
#  '4-5 weeks 100 - 5000',
#  '5-6 weeks 1000 - 30000',
#  '6-7 weeks 2500 - 80000',
#  '7-8 weeks 23000 - 150000',
#  '8-9 weeks 27000 - 230000',
#  '9-13 weeks 21000 - 290000',
#  '2nd trimester 6000 - 100000',
#  '3rd trimester 3000 - 80000',
#  'Non Pregnant female - less than 5 IU/L',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Requested: 02/02/2024 Collected: 02/02/2024 Reported: 13/02/2024 17:17',
#  'Date 29/01/19 28/07/23 31/01/24 02/02/24',
#  'Time F-Fast 1640 0839 F 0727 F 1429',
#  'Lab ID 295348768 885515368 838828312 839050249 Units Reference',
#  'Calcium 2.40 2.39 mmol/L ',
#  'Corr Calcium 2.34 2.27 mmol/L ',
#  'Albumin 46 44 46 H 49 g/L ',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Requested: 02/02/2024 Collected: 02/02/2024 Reported: 13/02/2024 17:17',
#  'Date 14/08/23 02/02/24',
#  'Time 1248 1429',
#  'Lab ID 887902883 839050249 Units Reference',
#  'R U-Creatinine 3.9 4.4 mmol/L',
#  'R U-Albumin 9.6 5.6 mg/L',
#  'R U-Alb/Creat 2.5 1.3 mg/mmol ',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Requested: 02/02/2024 Collected: 02/02/2024 Reported: 13/02/2024 17:17',
#  'pH 6 Protein Nil Glucose Nil',
#  'Specific gravity 1.007 ',
#  'Leucocytes 0 x10*6/L ',
#  'Erythrocytes 0 x10*6/L ',
#  'Epithelial cells 5 x10*6/L',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU, Urinel, Urine2, Urine3',
#  'Your Reference: Lab Reference: 8removed',
#  'Requested: 05/02/2024 Collected: 05/02/2024 Reported: 13/02/2024 17:17',
#  'Date 14/08/23 31/01/24 02/02/24 05/02/24',
#  'Time F-Fast 1248 O727 F 1429 1341',
#  'Lab ID 887902883 838828312 839050249 838828414 Units Reference',
#  'Sodium 139 140 138 mmol/L ',
#  'Potassium 4.8 4.5 4.5 mmol/L ',
#  'Chloride 107 106 108 mmol/L ',
#  'Bicarbonate 21 25 23 mmol/L ',
#  'Urea 5.3 5.1 5.2 mmol/L ',
#  'Creatinine 65 65 70 umol/L ',
#  'eGFR >90 >90 >90 mL/min/1.73m2 ',
#  'Urate 0.20 0.21 mmol/L ',
#  'Calcium 2.40 2.39 2.37 mmol/L ',
#  'Corr Calcium 2.34 2.27 2.33 mmol/L ',
#  'Phosphate. 1.08 1.06 mmol/L ',
#  'Bili.Total H 18 10 umol/L ',
#  'ALP 70 68 U/L ',
#  'GGT 15 14 U/L ',
#  'LD 178 185 U/L ',
#  'AST 23 18 U/L ',
#  'ALT 22 15 U/L ',
#  'Total Protein 72 70 g/L ',
#  'Albumin 46 H 49 45 g/L ',
#  'Globulin 26 25 g/L ',
#  'Cholesterol 4.7 4.2 mmol/L ',
#  'Triglycerides 0.6 0.9 mmol/L ',
#  'Comments on Collection 05/02/24 1341:',
#  'NATA Accreditation No 2178',
#  'Requested: 02/02/2024 Collected: 05/02/2024 Reported: 13/02/2024 17:17',
#  'Intact Parathyroid Hormone 3.5 pmol/L ',
#  'Calcium 2.39 mmol/L ',
#  'Corrected Calcium 2.27 mmol/L ',
#  'Albumin H 49 g/L ',
#  'Comment on Lab ID 839050249',
#  '# Please note PTH collection date: 05/02/2024 13:43',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Requested: 05/02/2024 Collected: 05/02/2024 Reported: 13/02/2024 17:17',
#  'Date 24/09/18 28/07/23 31/01/24 05/02/24',
#  'Time F-Fast 1100 0839 F Q727 F 1341',
#  'Lab ID 282139635 885515368 838828312 838828414 Units Reference',
#  'F Gluc Plasma 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'R Gluc Serum 5.5 mmol/L ',
#  'NATA Accreditation No 2178',
#  'Requested: 05/02/2024 Collected: 05/02/2024 Reported: 13/02/2024 17:17',
#  'Date 23/12/17 31/01/24 05/02/24',
#  'Time F-Fast 0825 F O727 F 1341',
#  'Lab ID 266516640 838828312 838828414 Units Reference',
#  'Cholesterol L 3.8 4.7 4.2 mmol/L ',
#  'Triglycerides 0.5 0.6 0.9 mmol/L ',
#  'HDL Chol. 1.6 2.0 1.6 mmol/L ',
#  'LDL Chol. 2.0 2.4 2.2 mmol/L ',
#  'Non-HDL Chol. 2.7 2.6 mmol/L ',
#  'Comments on Collection 05/02/24 1341:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Requested: 03/02/2024 Collected: 06/02/2024 Reported: 13/02/2024 17:17',
#  'Start date and time 05/02/2024 13:52',
#  'End date and time 06/02/2024 13:00',
#  'Average BP 127/85 mmHg ',
#  'Average BP 130/89 mmHg ',
#  'Average BP 120/72 mmHg ',
#  'Date reported 06/02/2024',
#  'Comment on Lab ID 839308720',
#  '1. People with associated clinical conditions or end-organ damage',
#  '24 hour 125/76 Night 112/67 Day 128/78',
#  '2. Hypertension with proteinuria >l g per day',
#  '24 hour 121/71 Night 107/63 Day 124/74',
#  '3. Pregnancy <22 weeks gestation 132/79',
#  '22-30 weeks gestation 133/81',
#  '>30 weeks gestation 135/86',
#  'Australia: 2011 consensus position statement. J Hypertens. 2012',
#  'Feb; 30  :253-66.)',
#  'before 12-02-2025. Use PIN 7661.',
#  'https://sdrviewer.apps.sonichealthcare.com/ ?GUID=FD73BA43-AE9C-4FA1-B54A-5A721557B246Ã©hostCode=D',
#  'HM&shareType=1l',
#  'NATA Accreditation No 2178',
#  'Requested: 03/02/2024 Collected: 06/02/2024 Reported: 06/02/2024 17:17',
#  'Clinical notes: 2? HYPERTENSION ?ANXIETY RELATED/WHITE COAT HYPERTENSION ',
#  'Start date and time 05/02/2024 13:52',
#  'End date and time 06/02/2024 13:00',
#  'Average BP 127/85 mmHg ',
#  'Average BP 130/89 mmHg ',
#  'Average BP 120/72 mmHg ',
#  'Date reported 06/02/2024',
#  'Comment on Lab ID 839308720',
#  '1. People with associated clinical conditions or end-organ damage',
#  '24 hour 125/76 Night 112/67 Day 128/78',
#  '2. Hypertension with proteinuria >l g per day',
#  '24 hour 121/71 Night 107/63 Day 124/74',
#  '3. Pregnancy <22 weeks gestation 132/79',
#  '22-30 weeks gestation 133/81',
#  '>30 weeks gestation 135/86',
#  'Australia: 2011 consensus position statement. J Hypertens. 2012',
#  'Feb; 30  :253-66.)',
#  'before 05-02-2025. Use PIN 1919.',
#  'https://sdrviewer.apps.sonichealthcare.com/ ?GUID=F74026BF-2 6 4A-4 9E9-8CF4-7025DBD8C5E5 Ã©hostCode=D',
#  'NATA Accreditation No 2178',
#  'Your Reference: 15992986 Lab Refremoved',
#  'Requested: 02/02/2024 Collected: 10/02/2024 Reported: 10/02/2024 10:46',
#  '==" â\x80\x9d Oo DOB:19/01/1989 Phone:',
#  'US RENAL 10/02/2024 Reference: 15992986',
#  'Right Kidney: 100 mm in length. There is no hydronephrosis, calculus',
#  'Left Kidney: 104 mm in length. There is no hydronephrosis, calculus',
#  'Bladder: Prevoid volume: 195 mL. Postvoid volume: 10 mL. The bladder',
#  'Electronically verified by: Dr Mark Fiorentino - 10/02/2024 10:43',
#  'Fully Rebatable 1.5T and 3T MRI - Same day appointments available at',
#  'Your Reference: 15992986 Lab Refremoved',
#  'Requested: 02/02/2024 Collected: 10/02/2024 Reported: 10/02/2024 10:46',
#  '=â\x80\x94_â\x80\x94â\x80\x94 â\x80\x94 ; .. 7 DOB:19/01/1989 Phone:',
#  'US RENAL 10/02/2024 Reference: 15992986',
#  'Right Kidney: 100 mm in length. There is no hydronephrosis, calculus',
#  'Left Kidney: 104 mm in length. There is no hydronephrosis, calculus',
#  'Bladder: Prevoid volume: 195 mL. Postvoid volume: 10 mL. The bladder',
#  'Electronically verified by: Dr Mark Fiorentino - 10/02/2024 10:43',
#  'Fully Rebatable 1.5T and 3T MRI - Same day appointments available at']

# %%
# Filter the list to keep only strings that contain a number
filtered_list = [s for s in filtered_list if not contains_date(s)]

filtered_list
# Out:
# ['Printed on 27th February 2024',
#  'Clinical notes: 2? UTI',
#  'pH 7 Protein Nil Glucose Nil',
#  'Specific gravity 1.012 ',
#  'Leucocytes 5 x10*6/L ',
#  'Erythrocytes H 14 x10*6/L ',
#  'Epithelial cells 5 x10*6/L',
#  'Comment on Lab ID 887475034',
#  'NATA Accreditation No 2178',
#  'Rubella IgG  11 IU/mL',
#  'Comment on Lab ID 838828312',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  'NATA Accreditation No 2178',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'history of type 2 diabetes.',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L ',
#  'Transferrin 2.2 2.5 2.7 g/L ',
#  'TIBC  50 56 60 umol/L ',
#  'Saturation 23 22 42 % ',
#  'Ferritin 38 719 39 47 ug/L ',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 31/01/24',
#  'Time F-Fast 0825 F 0727 F',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 Â£L ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'wcc 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 milU/L ',
#  'NATA Accreditation No 2178',
#  'Date 28/07/23 31/01/24',
#  'Time F-Fast 0839 F 0727 F',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'NATA Accreditation No 2178',
#  'Date 24/09/18 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 1100 1640 0839 F 0727 F',
#  'Lab ID 282139635 295348768 885515368 838828312 Units Reference',
#  'Haemoglobin 124 128 127 134 g/L ',
#  'RCC 4.2 4.3 4.2 4.5 x10*12/L ',
#  'Haematocrit 0.38 0.38 0.37 0.41 ',
#  'MCV 90 88 87 92 fL ',
#  'MCH 29.6 29.8 30.0 29.9 pg ',
#  'MCHC 328 338 344 325 g/L ',
#  'RDW 11.9 11.9 12.4 13.0 ',
#  'WCC 7.7 8.4 9.3 7.9 x10*9/L ',
#  'Neutrophils 4.32 4.50 4.69 4.11 x10*9/L ',
#  'Lymphocytes 2.77 2.96 3.67 2.96 x10*9/L ',
#  'Monocytes 0.52 0.76 0.63 0.59 x10*9/L ',
#  'Eosinophils 0.07 0.11 0.22 0.17 x10*9/L ',
#  'Basophils 0.04 0.07 0.04 0.04 x10*9/L ',
#  'NRBC <1.0 <1.0 <1.0 <1.0 /100 WBC ',
#  'Platelets 221 267 234 261 x10*9/L ',
#  'ESR 1 mm/h ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Date 29/01/19 28/07/23 14/08/23 31/01/24',
#  'Time F-Fast 1640 0839 F 1248 0727 F',
#  'Lab ID 295348768 885515368 887902883 838828312 Units Reference',
#  'Sodium 140 L 134 139 140 mmol/L ',
#  'Potassium 4.9 5.5 4.8 4.5 mmol/L ',
#  'Chloride 106 106 107 106 mmol/L ',
#  'Bicarbonate 23 21 21 25 mmol/L ',
#  'Urea 4.0 4.8 5.3 5.1 mmol/L ',
#  'Creatinine 70 70 65 65 umol/L ',
#  'eGFR >90 >90 >90 >90 mL/min/1.73m2 ',
#  'Calcium 2.40 mmol/L ',
#  'Corr Calcium 2.34 mmol/L ',
#  'Magnesium. 0.84 mmol/L ',
#  'Phosphate. 1.08 mmol/L ',
#  'Bili.Total 11 H 20 H 18 umol/L ',
#  'ALP 59 60 70 U/L ',
#  'GGT 13 11 15 U/L ',
#  'LD 187 203 178 U/L ',
#  'AST 19 25 23 U/L ',
#  'ALT 16 12 22 U/L ',
#  'Total Protein 76 70 72 g/L ',
#  'Albumin 46 44 46 g/L ',
#  'Globulin 30 26 26 g/L ',
#  'Cholesterol 4.7 mmol/L ',
#  'Triglycerides 0.6 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 24/09/18 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1100 0839 F 0727 F',
#  'Lab ID 266516640 282139635 885515368 838828312 Units Reference',
#  'F Gluc Plasma 4.5 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  'Diabetes is unlikely if fasting glucose levels are less than 5.5 mmol/L but',
#  'history of type 2 diabetes.',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 31/01/24',
#  'Time F-Fast 0825 F 0727 F',
#  'Lab ID 266516640 838828312 Units Reference',
#  'Cholesterol L 3.8 4.7 mmol/L ',
#  'Triglycerides 0.5 0.6 mmol/L ',
#  'HDL Chol. 1.6 2.0 mmol/L ',
#  'LDL Chol. 2.0 2.4 mmol/L ',
#  'Non-HDL Chol. 2.7 mmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Hepatitis B Surface Ab 31 IU/L',
#  'Comment on Lab ID 838828312',
#  'NATA Accreditation No 2178',
#  'Rubella IgG  11 IU/mL',
#  'Comment on Lab ID 838828312',
#  '<5 IU/mL: Not immune',
#  '5-9 IU/mL: Equivocal',
#  '>/=10 IU/mL: Immune',
#  'NATA Accreditation No 2178',
#  'Date 28/07/23 31/01/24',
#  'Time F-Fast 0839 F 0727 F',
#  'Lab ID 885515368 838828312 Units Reference',
#  'Vitamin D 73 83 nmol/L ',
#  'Comments on Collection 31/01/24 0727 F:',
#  "Australia and New Zealand' MJA, 196:686-687, 2012, Vitamin D status is",
#  'Mild Deficiency 30 - 49 nmol/L',
#  'Moderate Deficiency 12.5 - 29 nmol/L',
#  'Severe Deficiency <12.5 nmol/L',
#  'Vitamin D adequacy can be defined as a level >49 nmol/L at the end of',
#  'winter - the level may need to be 10 - 20 nmol/L higher at the end of',
#  'From lst November 2014, Medicare rebates for vitamin D testing will apply',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 29/01/19 28/07/23 31/01/24',
#  'Time F-Fast 0825 F 1640 0839 F 0727 F',
#  'Lab ID 266516640 295348768 885515368 838828312 Units Reference',
#  'Tron 11.5 12.2 24.9 umol/L ',
#  'Transferrin 2.2 2.5 2.7 g/L ',
#  'TIBC  50 56 60 umol/L ',
#  'Saturation 23 22 42 % ',
#  'Ferritin 38 79 39 47 ug/L ',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 24/09/18 14/08/23 31/01/24',
#  'Time F-Fast 0825 F 1100 1248 0727 F',
#  'Lab ID 266516640 282139635 887902883 838828312 Units Reference',
#  'TSH 1.14 1.18 1.57 2.99 mIU/L ',
#  'NATA Accreditation No 2178',
#  'Date 29/01/19 02/02/24',
#  'Time 1640 1429',
#  'Lab ID 295348768 839050249 Units Reference',
#  'BhcG  <5 <5 IU/L',
#  'Comments on Collection 02/02/24 1429:',
#  '4 weeks 16 - 160',
#  '4-5 weeks 100 - 5000',
#  '5-6 weeks 1000 - 30000',
#  '6-7 weeks 2500 - 80000',
#  '7-8 weeks 23000 - 150000',
#  '8-9 weeks 27000 - 230000',
#  '9-13 weeks 21000 - 290000',
#  '2nd trimester 6000 - 100000',
#  '3rd trimester 3000 - 80000',
#  'Non Pregnant female - less than 5 IU/L',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Date 29/01/19 28/07/23 31/01/24 02/02/24',
#  'Time F-Fast 1640 0839 F 0727 F 1429',
#  'Lab ID 295348768 885515368 838828312 839050249 Units Reference',
#  'Calcium 2.40 2.39 mmol/L ',
#  'Corr Calcium 2.34 2.27 mmol/L ',
#  'Albumin 46 44 46 H 49 g/L ',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Date 14/08/23 02/02/24',
#  'Time 1248 1429',
#  'Lab ID 887902883 839050249 Units Reference',
#  'R U-Creatinine 3.9 4.4 mmol/L',
#  'R U-Albumin 9.6 5.6 mg/L',
#  'R U-Alb/Creat 2.5 1.3 mg/mmol ',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'pH 6 Protein Nil Glucose Nil',
#  'Specific gravity 1.007 ',
#  'Leucocytes 0 x10*6/L ',
#  'Erythrocytes 0 x10*6/L ',
#  'Epithelial cells 5 x10*6/L',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU, Urinel, Urine2, Urine3',
#  'Your Reference: Lab Reference: 8removed',
#  'Date 14/08/23 31/01/24 02/02/24 05/02/24',
#  'Time F-Fast 1248 O727 F 1429 1341',
#  'Lab ID 887902883 838828312 839050249 838828414 Units Reference',
#  'Sodium 139 140 138 mmol/L ',
#  'Potassium 4.8 4.5 4.5 mmol/L ',
#  'Chloride 107 106 108 mmol/L ',
#  'Bicarbonate 21 25 23 mmol/L ',
#  'Urea 5.3 5.1 5.2 mmol/L ',
#  'Creatinine 65 65 70 umol/L ',
#  'eGFR >90 >90 >90 mL/min/1.73m2 ',
#  'Urate 0.20 0.21 mmol/L ',
#  'Calcium 2.40 2.39 2.37 mmol/L ',
#  'Corr Calcium 2.34 2.27 2.33 mmol/L ',
#  'Phosphate. 1.08 1.06 mmol/L ',
#  'Bili.Total H 18 10 umol/L ',
#  'ALP 70 68 U/L ',
#  'GGT 15 14 U/L ',
#  'LD 178 185 U/L ',
#  'AST 23 18 U/L ',
#  'ALT 22 15 U/L ',
#  'Total Protein 72 70 g/L ',
#  'Albumin 46 H 49 45 g/L ',
#  'Globulin 26 25 g/L ',
#  'Cholesterol 4.7 4.2 mmol/L ',
#  'Triglycerides 0.6 0.9 mmol/L ',
#  'Comments on Collection 05/02/24 1341:',
#  'NATA Accreditation No 2178',
#  'Intact Parathyroid Hormone 3.5 pmol/L ',
#  'Calcium 2.39 mmol/L ',
#  'Corrected Calcium 2.27 mmol/L ',
#  'Albumin H 49 g/L ',
#  'Comment on Lab ID 839050249',
#  'NATA Accreditation No 2178',
#  'Tests Completed: HCG Quant,Ca,RU-Malb, PTH,MSU,Urinel, Urine2, Urine3',
#  'Date 24/09/18 28/07/23 31/01/24 05/02/24',
#  'Time F-Fast 1100 0839 F Q727 F 1341',
#  'Lab ID 282139635 885515368 838828312 838828414 Units Reference',
#  'F Gluc Plasma 4.7 mmol/L ',
#  'R Gluc Plasma 4.5 mmol/L ',
#  'F Gluc Serum 4.8 mmol/L ',
#  'R Gluc Serum 5.5 mmol/L ',
#  'NATA Accreditation No 2178',
#  'Date 23/12/17 31/01/24 05/02/24',
#  'Time F-Fast 0825 F O727 F 1341',
#  'Lab ID 266516640 838828312 838828414 Units Reference',
#  'Cholesterol L 3.8 4.7 4.2 mmol/L ',
#  'Triglycerides 0.5 0.6 0.9 mmol/L ',
#  'HDL Chol. 1.6 2.0 1.6 mmol/L ',
#  'LDL Chol. 2.0 2.4 2.2 mmol/L ',
#  'Non-HDL Chol. 2.7 2.6 mmol/L ',
#  'Comments on Collection 05/02/24 1341:',
#  ' Consensus Statement 2016 and the Australasian Association of',
#  'Guideline 2018.',
#  'Total cholesterol <4.0 mmol/L',
#  'Triglyceride <2.0 mmol/L',
#  'HDL cholesterol >1.0 mmol/L',
#  'LDL cholesterol <2.5 mmol/L ',
#  'Non-HDL cholesterol <3.3 mmol/L ',
#  'Target values from the AACB Lipid Reporting Guideline 2018.',
#  'NATA Accreditation No 2178',
#  'Average BP 127/85 mmHg ',
#  'Average BP 130/89 mmHg ',
#  'Average BP 120/72 mmHg ',
#  'Comment on Lab ID 839308720',
#  '1. People with associated clinical conditions or end-organ damage',
#  '24 hour 125/76 Night 112/67 Day 128/78',
#  '2. Hypertension with proteinuria >l g per day',
#  '24 hour 121/71 Night 107/63 Day 124/74',
#  '3. Pregnancy <22 weeks gestation 132/79',
#  '22-30 weeks gestation 133/81',
#  '>30 weeks gestation 135/86',
#  'Australia: 2011 consensus position statement. J Hypertens. 2012',
#  'Feb; 30  :253-66.)',
#  'before 12-02-2025. Use PIN 7661.',
#  'https://sdrviewer.apps.sonichealthcare.com/ ?GUID=FD73BA43-AE9C-4FA1-B54A-5A721557B246Ã©hostCode=D',
#  'HM&shareType=1l',
#  'NATA Accreditation No 2178',
#  'Clinical notes: 2? HYPERTENSION ?ANXIETY RELATED/WHITE COAT HYPERTENSION ',
#  'Average BP 127/85 mmHg ',
#  'Average BP 130/89 mmHg ',
#  'Average BP 120/72 mmHg ',
#  'Comment on Lab ID 839308720',
#  '1. People with associated clinical conditions or end-organ damage',
#  '24 hour 125/76 Night 112/67 Day 128/78',
#  '2. Hypertension with proteinuria >l g per day',
#  '24 hour 121/71 Night 107/63 Day 124/74',
#  '3. Pregnancy <22 weeks gestation 132/79',
#  '22-30 weeks gestation 133/81',
#  '>30 weeks gestation 135/86',
#  'Australia: 2011 consensus position statement. J Hypertens. 2012',
#  'Feb; 30  :253-66.)',
#  'before 05-02-2025. Use PIN 1919.',
#  'https://sdrviewer.apps.sonichealthcare.com/ ?GUID=F74026BF-2 6 4A-4 9E9-8CF4-7025DBD8C5E5 Ã©hostCode=D',
#  'NATA Accreditation No 2178',
#  'Your Reference: 15992986 Lab Refremoved',
#  'Right Kidney: 100 mm in length. There is no hydronephrosis, calculus',
#  'Left Kidney: 104 mm in length. There is no hydronephrosis, calculus',
#  'Bladder: Prevoid volume: 195 mL. Postvoid volume: 10 mL. The bladder',
#  'Fully Rebatable 1.5T and 3T MRI - Same day appointments available at',
#  'Your Reference: 15992986 Lab Refremoved',
#  'Right Kidney: 100 mm in length. There is no hydronephrosis, calculus',
#  'Left Kidney: 104 mm in length. There is no hydronephrosis, calculus',
#  'Bladder: Prevoid volume: 195 mL. Postvoid volume: 10 mL. The bladder',
#  'Fully Rebatable 1.5T and 3T MRI - Same day appointments available at']

# %%
def param_lister(sample_list, params_df):
    
    # make sample and synonyms lowercase
    sample_list = [s.lower() for s in sample_list]
    params_df['Synonyms'] = [[w.lower() for w in s] for s in params_df['Synonyms']]
    
    # initialise lists to be used for resulting output
    params = []
    matching_synonyms = []
    units = []
    values = []
    line_numbers = []
    
    for i, line in enumerate(sample_list):
        detected = []
        abbrev_no = []
        for j, synonyms in enumerate(params_df['Synonyms']):
            for synonym in synonyms:
                
                pattern = r'\b' + synonym + r'\b'
                # Use only strict matching for shorter length synonyms
                if len(synonym) < 5:
                    # Check if the pattern matches the line
                    if re.search(pattern, line):
                        detected.append(synonym)
                        abbrev_no.append(j)
                
                # Use fuzzy matching for longer length synonyms
                elif re.search(pattern, line) or fuzz.partial_ratio(synonym, line) >= 85:
                    detected.append(synonym)
                    abbrev_no.append(j)
       
        if detected:            
            # Select the parameter detected from the line as the abbreviation for the longest detected synonym
            param = params_df['Abbreviation'][abbrev_no[np.argmax([len(s) for s in detected])]]
            matching_synonym = max(detected, key = len)
            
            # Split line up into elements
            elements = re.split(r'\s+', line)
            
            # Find the unit by finding element that contains / or %
            # Make sure it is the last matching element
            unit = None
            for element in reversed(elements):
                if '/' in element or '%' in element:
                    unit = element
                    elements.remove(element)
                    break
            
            # Find the unit by finding element that only contains numbers
            # Make sure it is the last matching element
            value = None
            for element in reversed(elements):
                if any(char.isdigit() for char in element):
                    value = element
                    break
            
            params.append(param)
            matching_synonyms.append(matching_synonym)
            units.append(unit)
            values.append(value)
            line_numbers.append(i)
            text = [sample_list[n] for n in line_numbers]
            df = pd.DataFrame({'param': params, 'unit': units,'value': values, 'line_number': line_numbers,'matching_synonym' : matching_synonyms, 'text': text})
            df.dropna(inplace=True)
            df.drop_duplicates(subset=['param'], keep='first', inplace=True)
            df.reset_index(drop=True, inplace=True)
    return df

# %%
# %%time
test = param_lister(filtered_list, params_json)
test
# Out:
# CPU times: total: 1min 22s
# Wall time: 1min 22s
#       param           unit value  line_number      matching_synonym  \
# 0       RBC        x10*6/l    14            5          erythrocytes
# 1      GGLO          iu/ml    11            9                   igg
# 2       Na+         mmol/l   140           18                sodium
# 3        K+         mmol/l   4.5           19             potassium
# 4       Cl-         mmol/l   106           20              chloride
# 5       CO2         mmol/l    25           21           bicarbonate
# 6      UREA         mmol/l   5.1           22                  urea
# 7      CREA         umol/l    65           23            creatinine
# 8      EGFR  ml/min/1.73m2   >90           24                  egfr
# 9      Ca2+         mmol/l  2.40           25               calcium
# 10      P5+         mmol/l  1.08           28             phosphate
# 11   BILIIN         umol/l    18           29                  bili
# 12      ALP            u/l    70           30                   alp
# 13      GGT            u/l    15           31                   ggt
# 14      AST            u/l    23           33                   ast
# 15      ALT            u/l    22           34                   alt
# 16     PROT            g/l    72           35         total protein
# 17      ALB            g/l    46           36               albumin
# 18    TRIGL         mmol/l   0.6           39         triglycerides
# 19     GLUC         mmol/l   4.7           45                  gluc
# 20    FGLUC         mmol/l   5.5           49  fasting glucose test
# 21     TFER            g/l   2.7           56           transferrin
# 22     FERR           ug/l    47           59              ferritin
# 23     CHOL         mmol/l   2.0           66                  chol
# 24    VLDLC         mmol/l  >1.0           73      vldl cholesterol
# 25   NONHDL         mmol/l  <3.3           75   non-hdl cholesterol
# 26    HBA1C            g/l   134           81        hemoglobin a1c
# 27     MCHC            g/l   325           86                  mchc
# 28      WBC        x10*9/l   7.9           88                   wcc
# 29     NEUT        x10*9/l  4.11           89           neutrophils
# 30  LYMPHO%        x10*9/l  2.96           90               lympho%
# 31     MONO        x10*9/l  0.59           91             monocytes
# 32      EOS        x10*9/l  0.17           92           eosinophils
# 33     BASO        x10*9/l  0.04           93             basophils
# 34    NRBCs           /100  <1.0           94                  nrbc
# 35     PLAT        x10*9/l   261           95             platelets
# 36      ESR           mm/h     1           96                   esr
# 37      TSH         milu/l  2.99          105                   tsh
# 38     vitD         nmol/l    83          110            vitamin d2
# 39     GALT         nmol/l    29          114       galt deficiency
# 40   PHEALA         nmol/l    20          117             phe level
# 41     URIC         mmol/l  0.21          283                 urate
# 42      PTH         pmol/l   3.5          300   parathyroid hormone
#
#                                                  text
# 0                          erythrocytes h 14 x10*6/l
# 1                               rubella igg  11 iu/ml
# 2                    sodium 140 l 134 139 140 mmol/l
# 3                   potassium 4.9 5.5 4.8 4.5 mmol/l
# 4                    chloride 106 106 107 106 mmol/l
# 5                     bicarbonate 23 21 21 25 mmol/l
# 6                        urea 4.0 4.8 5.3 5.1 mmol/l
# 7                      creatinine 70 70 65 65 umol/l
# 8                 egfr >90 >90 >90 >90 ml/min/1.73m2
# 9                                calcium 2.40 mmol/l
# 10                            phosphate. 1.08 mmol/l
# 11                    bili.total 11 h 20 h 18 umol/l
# 12                                  alp 59 60 70 u/l
# 13                                  ggt 13 11 15 u/l
# 14                                  ast 19 25 23 u/l
# 15                                  alt 16 12 22 u/l
# 16                        total protein 76 70 72 g/l
# 17                              albumin 46 44 46 g/l
# 18                          triglycerides 0.6 mmol/l
# 19                      f gluc plasma 4.5 4.7 mmol/l
# 20  diabetes is unlikely if fasting glucose levels...
# 21                       transferrin 2.2 2.5 2.7 g/l
# 22                        ferritin 38 719 39 47 ug/l
# 23                          hdl chol. 1.6 2.0 mmol/l
# 24                        hdl cholesterol >1.0 mmol/l
# 25                   non-hdl cholesterol <3.3 mmol/l
# 26                   haemoglobin 124 128 127 134 g/l
# 27                          mchc 328 338 344 325 g/l
# 28                       wcc 7.7 8.4 9.3 7.9 x10*9/l
# 29           neutrophils 4.32 4.50 4.69 4.11 x10*9/l
# 30           lymphocytes 2.77 2.96 3.67 2.96 x10*9/l
# 31             monocytes 0.52 0.76 0.63 0.59 x10*9/l
# 32           eosinophils 0.07 0.11 0.22 0.17 x10*9/l
# 33             basophils 0.04 0.07 0.04 0.04 x10*9/l
# 34                 nrbc <1.0 <1.0 <1.0 <1.0 /100 wbc
# 35                 platelets 221 267 234 261 x10*9/l
# 36                                        esr 1 mm/h
# 37                    tsh 1.14 1.18 1.57 2.99 milu/l
# 38                            vitamin d 73 83 nmol/l
# 39               moderate deficiency 12.5 - 29 nmol/l
# 40  winter - the level may need to be 10 - 20 nmol...
# 41                            urate 0.20 0.21 mmol/l
# 42             intact parathyroid hormone 3.5 pmol/l

# %% [markdown]
# issues spotted
#
# - Row  1: No "Rubella" in the parameter json so "Rubella IgG" has just been identified as "IgG"
# - Row 20: fasting glucose test reading picked up from likely recommendation
# - Row 23: "vldl cholesterol" from "hdl cholesterol"
# - Row 39: "galt deficiency" from "moderate deficiency"
# - Row 40: "phe level" from "winter - the level may need to be 10 - 20 nmol..."

# %% [markdown]
# # Putting all together to test

# %%
# Create raw_text cleaner function
def sample_cleaner(raw_sample):
    
    # Split raw sample into list of its lines
    sample_list = raw_sample.split('\n')
    
    # Remove parenthesis and contents
    sample_list = [re.sub(r'[\(\[][^\)\]]*[\)\]]', '', line) for line in sample_list]
    
    # Remove dates from lines
    sample_list = [re.sub(r'\b\d{2}/\d{2}/\d{2,4}\b', '', line) for line in sample_list]
    
    # Only keep lines with numbers in them
    sample_list = [line for line in sample_list if re.search(r'\d', line)]
    
    
    return sample_list

# %%
# apply cleaner function to all samples
samples['cleaned_text'] = samples['raw_text'].apply(sample_cleaner)
samples
# Out:
#                                             raw_text        date  \
# 0  Patient Name;, \nPatient Address: \n\nD.O.B: 2...  10/12/2018
# 1  Patient Health Summary\n\nremoved\n\nremoved\n...  13/02/2024
# 2  iilaverty -â- Pathology Report resuits @RCPA...  18/01/2024
# 3   \n\nHAEMATOLOGY\n\n \n15\nBLOOD - EDTA Result...     missing
# 4  ilaverty Pathology Report resus\n\npathology E...  18/01/2024
# 5  AUSTRALIAN LABORATORY 3427-18703 Referred: 02/...  02/04/2019
# 6  \n\n \n\n \n\n  \n \n  \n \n \n \n \n\n29 APR\...  26/94/2019
# 7  Peghy Â«Ao Â¢4 AG +48 | 38 â> CLINICAL LABOR...  02/02/2024
# 8  Patient Name ee Barcode ; [eennnennninittte\n\...  03/03/2022
#
#                                         cleaned_text  \
# 0  [TSH  miIU/L 0.73 0.82 0.64 0.46, FT4  pmol/L ...
# 1  [Printed on 27th February 2024, Requested:  Co...
# 2  [Reported  05:13 PM, INSULIN-LIKE GROWTH FACTO...
# 3  [15, ESR 2 0-20 mm/h @, HAEMOGLOBIN 122 110-15...
# 4  [2019, DOB Age 50 years Sex, Reported 18/01/20...
# 5  [AUSTRALIAN LABORATORY 3427-18703 Referred: , ...
# 6  [29 APR, 64+ Yrs DOB:  Sex: Male, Time: 15:40 ...
# 7  [Peghy Â«Ao Â¢4 AG +48 | 38 â> CLINICAL LABO...
# 8  [Age: Gender : 64/Female Sample Collected On :...
#
#                                            params_df
# 0       param            unit   value  line_numbe...
# 1        param           unit value  line_number ...
# 2     param    unit  value  line_number  matching...
# 3            param             unit        value ...
# 4     param    unit  value  line_number  matching...
# 5        param           unit value  line_number ...
# 6    param          unit      value  line_number ...
# 7         param           unit value  line_number...
# 8    param   unit   value  line_number matching_s...

# %%
# %%time
# Apply created param function to all samples
samples['params_df'] = samples['cleaned_text'].apply(lambda x: param_lister(x, params_json))
# Out:
# CPU times: total: 3min 54s
# Wall time: 3min 54s

# %%
# View full dataframe
samples
# Out:
#                                             raw_text        date  \
# 0  Patient Name;, \nPatient Address: \n\nD.O.B: 2...  10/12/2018
# 1  Patient Health Summary\n\nremoved\n\nremoved\n...  13/02/2024
# 2  iilaverty -â- Pathology Report resuits @RCPA...  18/01/2024
# 3   \n\nHAEMATOLOGY\n\n \n15\nBLOOD - EDTA Result...     missing
# 4  ilaverty Pathology Report resus\n\npathology E...  18/01/2024
# 5  AUSTRALIAN LABORATORY 3427-18703 Referred: 02/...  02/04/2019
# 6  \n\n \n\n \n\n  \n \n  \n \n \n \n \n\n29 APR\...  26/94/2019
# 7  Peghy Â«Ao Â¢4 AG +48 | 38 â> CLINICAL LABOR...  02/02/2024
# 8  Patient Name ee Barcode ; [eennnennninittte\n\...  03/03/2022
#
#                                         cleaned_text  \
# 0  [TSH  miIU/L 0.73 0.82 0.64 0.46, FT4  pmol/L ...
# 1  [Printed on 27th February 2024, Requested:  Co...
# 2  [Reported  05:13 PM, INSULIN-LIKE GROWTH FACTO...
# 3  [15, ESR 2 0-20 mm/h @, HAEMOGLOBIN 122 110-15...
# 4  [2019, DOB Age 50 years Sex, Reported 18/01/20...
# 5  [AUSTRALIAN LABORATORY 3427-18703 Referred: , ...
# 6  [29 APR, 64+ Yrs DOB:  Sex: Male, Time: 15:40 ...
# 7  [Peghy Â«Ao Â¢4 AG +48 | 38 â> CLINICAL LABO...
# 8  [Age: Gender : 64/Female Sample Collected On :...
#
#                                            params_df
# 0       param            unit   value  line_numbe...
# 1        param           unit value  line_number ...
# 2     param    unit  value  line_number  matching...
# 3            param             unit        value ...
# 4     param    unit  value  line_number  matching...
# 5        param           unit value  line_number ...
# 6    param          unit value  line_number     m...
# 7         param           unit value  line_number...
# 8    param   unit   value  line_number matching_s...

# %%
# Check through how each sample performed
samples['params_df'][6]
# Out:
#   param          unit value  line_number     matching_synonym  \
# 0   Na+        mmol/l   142            3               sodium
# 1    K+        mmol/l   4.0            4            potassium
# 2   Cl-        mmol/l   106            5             chloride
# 3   CO2        mmol/l    28            6          bicarbonate
# 4  UREA        mmol/l   4.1            7                 urea
# 5  CREA        umol/l    89            8           creatinine
# 6  EGFR  ml/mn/1.73m2    79            9                 egfr
# 7  URIC        mmol/l  0.44           10            uric acid
# 8  Ca2+        mmol/l  2.40           11              calcium
# 9   P5+        mmol/l  1.12           14  inorganic phosphate
#
#                                text
# 0                sodium 142 mmol/l
# 1             potassium 4.0 mmol/l
# 2              chloride 106 mmol/l
# 3            bicarbonate 28 mmol/l
# 4                  urea 4.1 mmol/l
# 5             creatinine 89 umol/l
# 6              egfr 79 ml/mn/1.73m2
# 7            uric acid 0.44 mmol/l
# 8              calcium 2.40 mmol/l
# 9  inorganic phosphate 1.12 mmol/l

# %% [markdown]
# # Final model

# %%
# Create final function that returns the disered output of list of dictionaries
def parameter_dictionary(raw_text, params_df):
    """
    Clean raw medical results
    Extracts parameters, values, unit into a list of dictionarys
    
    Parameters:
        raw_text(string): The raw medical data
        params_df: Dataframe of parameter abbreviations and synonyms from json file
        
    Returns:
        list: List of dictionaries ("parameter", "value", "unit")
    
    """
    
    # Convert all string values in params df to lowercase, including strings within lists
    params_df = pd.DataFrame({col: [item.lower() if isinstance(item, str) else [subitem.lower() for subitem in item]
                                    for item in params_json[col]] for col in params_json.columns})
    # Convert raw text to lower case
    lower_text = raw_text.lower()
    
    # Format the params df
    # Group the synonyms of the parameters that appear more than once.
    params_df = params_df.groupby('Abbreviation')['Synonyms'].agg(lambda x: sum(x, [])).reset_index()
    # Add the abbreviation to the synonyms row
    params_df['Synonyms'] = params_df.apply(lambda row: [row['Abbreviation']] + row['Synonyms'], axis =1)
    
    # Clean raw text
    # Split raw sample into list of its lines
    sample_list = lower_text.split('\n')
    # Remove parenthesis and contents
    sample_list = [re.sub(r'\([^()]*\)|\[[^\[\]]*\]', '', line) for line in sample_list]
    # Remove dates from lines
    sample_list = [re.sub(r'\b\d{2}/\d{2}/\d{2,4}\b', '', line) for line in sample_list]
    # Only keep lines with numbers in them
    sample_list = [line for line in sample_list if re.search(r'\d', line)] 
    
    # initialise lists to be used for resulting output
    output_list = []
    seen_params = set()
    
    for line in sample_list:
        # Initialise variables to store detected parameters in line
        detected = []
        abbrev_no = []
        #iterate through each synonym in the parameter df to find any matching in the line
        for j, synonyms in enumerate(params_df['Synonyms']):
            for synonym in synonyms:
                
                # Use regex pattern to maken sure matching synonym is a complete word for strict matching
                pattern = r'\b' + synonym + r'\b'
                # Use only strict matching for shorter length synonyms
                if len(synonym) < 5:
                    # Check if the pattern matches the line
                    if re.search(pattern, line):
                        detected.append(synonym)
                        abbrev_no.append(j)
                
                # Use fuzzy matching as well for longer length synonyms to account for slight recording errors
                elif re.search(pattern, line) or fuzz.partial_ratio(synonym, line) >= 85:
                    detected.append(synonym)
                    abbrev_no.append(j)
       
        # look for values if a synonym has ben detected
        if detected:            
            # Select the parameter detected from the line as the abbreviation for the longest detected synonym
            param = params_df['Abbreviation'][abbrev_no[np.argmax([len(s) for s in detected])]]
            matching_synonym = max(detected, key = len)
            
            # Split line up on spaces into elements
            elements = re.split(r'\s+', line)
            
            # Find the unit by finding element that contains / or %
            # Make sure it is the last matching element
            unit = None
            for element in reversed(elements):
                if '/' in element or '%' in element:
                    unit = element
                    elements.remove(element)
                    break
            
            # Find the unit by finding element that only contains numbers
            # Make sure it is the last matching element
            value = None
            for element in reversed(elements):
                if any(char.isdigit() for char in element):
                    value = element
                    break
            
            # Only add recording dictionary if all keys have values
            if all([param, value, unit]):
                # Only add the recording if the parameter hasn't been recorded already
                if param not in seen_params:
                    output_list.append({
                        "parameter": param,
                        "value": value,
                        "unit": unit
                    })
                    seen_params.add(param)
    
    return output_list

# %%
# Load raw files
with open('0b8706dc-c9af-4c6b-887d-2f85b5a511e7.txt', 'r', encoding='latin1') as f:
    raw_text = f.read()
    
params_json = pd.read_json('X1.json')

# %%
# %%time
# Use function on files and analyse results
results = parameter_dictionary(raw_text, params_json)
results
# Out:
# CPU times: total: 1min 25s
# Wall time: 1min 25s
# [{'parameter': 'rbc', 'value': '14', 'unit': 'x10*6/l'},
#  {'parameter': 'gglo', 'value': '11', 'unit': 'iu/ml'},
#  {'parameter': 'na+', 'value': '140', 'unit': 'mmol/l'},
#  {'parameter': 'k+', 'value': '4.5', 'unit': 'mmol/l'},
#  {'parameter': 'cl-', 'value': '106', 'unit': 'mmol/l'},
#  {'parameter': 'co2', 'value': '25', 'unit': 'mmol/l'},
#  {'parameter': 'urea', 'value': '5.1', 'unit': 'mmol/l'},
#  {'parameter': 'crea', 'value': '65', 'unit': 'umol/l'},
#  {'parameter': 'egfr', 'value': '>90', 'unit': 'ml/min/1.73m2'},
#  {'parameter': 'ca2+', 'value': '2.40', 'unit': 'mmol/l'},
#  {'parameter': 'p5+', 'value': '1.08', 'unit': 'mmol/l'},
#  {'parameter': 'biliin', 'value': '18', 'unit': 'umol/l'},
#  {'parameter': 'alp', 'value': '70', 'unit': 'u/l'},
#  {'parameter': 'ggt', 'value': '15', 'unit': 'u/l'},
#  {'parameter': 'ast', 'value': '23', 'unit': 'u/l'},
#  {'parameter': 'alt', 'value': '22', 'unit': 'u/l'},
#  {'parameter': 'prot', 'value': '72', 'unit': 'g/l'},
#  {'parameter': 'alb', 'value': '46', 'unit': 'g/l'},
#  {'parameter': 'trigl', 'value': '0.6', 'unit': 'mmol/l'},
#  {'parameter': 'gluc', 'value': '4.7', 'unit': 'mmol/l'},
#  {'parameter': 'fgluc', 'value': '5.5', 'unit': 'mmol/l'},
#  {'parameter': 'tfer', 'value': '2.7', 'unit': 'g/l'},
#  {'parameter': 'ferr', 'value': '47', 'unit': 'ug/l'},
#  {'parameter': 'chol', 'value': '2.0', 'unit': 'mmol/l'},
#  {'parameter': 'vldlc', 'value': '>1.0', 'unit': 'mmol/l'},
#  {'parameter': 'nonhdl', 'value': '<3.3', 'unit': 'mmol/l'},
#  {'parameter': 'hba1c', 'value': '134', 'unit': 'g/l'},
#  {'parameter': 'mchc', 'value': '325', 'unit': 'g/l'},
#  {'parameter': 'wbc', 'value': '7.9', 'unit': 'x10*9/l'},
#  {'parameter': 'neut', 'value': '4.11', 'unit': 'x10*9/l'},
#  {'parameter': 'lympho%', 'value': '2.96', 'unit': 'x10*9/l'},
#  {'parameter': 'mono', 'value': '0.59', 'unit': 'x10*9/l'},
#  {'parameter': 'eos', 'value': '0.17', 'unit': 'x10*9/l'},
#  {'parameter': 'baso', 'value': '0.04', 'unit': 'x10*9/l'},
#  {'parameter': 'nrbcs', 'value': '<1.0', 'unit': '/100'},
#  {'parameter': 'plat', 'value': '261', 'unit': 'x10*9/l'},
#  {'parameter': 'esr', 'value': '1', 'unit': 'mm/h'},
#  {'parameter': 'tsh', 'value': '2.99', 'unit': 'milu/l'},
#  {'parameter': 'vitd', 'value': '83', 'unit': 'nmol/l'},
#  {'parameter': 'galt', 'value': '29', 'unit': 'nmol/l'},
#  {'parameter': 'pheala', 'value': '20', 'unit': 'nmol/l'},
#  {'parameter': 'uric', 'value': '0.21', 'unit': 'mmol/l'},
#  {'parameter': 'pth', 'value': '3.5', 'unit': 'pmol/l'}]

# %%
# Check code works the same as earlier testing function
print(len(results))
print(len(test))

test
# Out:
# 43
# 43
#       param           unit value  line_number      matching_synonym  \
# 0       RBC        x10*6/l    14            5          erythrocytes
# 1      GGLO          iu/ml    11            9                   igg
# 2       Na+         mmol/l   140           18                sodium
# 3        K+         mmol/l   4.5           19             potassium
# 4       Cl-         mmol/l   106           20              chloride
# 5       CO2         mmol/l    25           21           bicarbonate
# 6      UREA         mmol/l   5.1           22                  urea
# 7      CREA         umol/l    65           23            creatinine
# 8      EGFR  ml/min/1.73m2   >90           24                  egfr
# 9      Ca2+         mmol/l  2.40           25               calcium
# 10      P5+         mmol/l  1.08           28             phosphate
# 11   BILIIN         umol/l    18           29                  bili
# 12      ALP            u/l    70           30                   alp
# 13      GGT            u/l    15           31                   ggt
# 14      AST            u/l    23           33                   ast
# 15      ALT            u/l    22           34                   alt
# 16     PROT            g/l    72           35         total protein
# 17      ALB            g/l    46           36               albumin
# 18    TRIGL         mmol/l   0.6           39         triglycerides
# 19     GLUC         mmol/l   4.7           45                  gluc
# 20    FGLUC         mmol/l   5.5           49  fasting glucose test
# 21     TFER            g/l   2.7           56           transferrin
# 22     FERR           ug/l    47           59              ferritin
# 23     CHOL         mmol/l   2.0           66                  chol
# 24    VLDLC         mmol/l  >1.0           73      vldl cholesterol
# 25   NONHDL         mmol/l  <3.3           75   non-hdl cholesterol
# 26    HBA1C            g/l   134           81        hemoglobin a1c
# 27     MCHC            g/l   325           86                  mchc
# 28      WBC        x10*9/l   7.9           88                   wcc
# 29     NEUT        x10*9/l  4.11           89           neutrophils
# 30  LYMPHO%        x10*9/l  2.96           90               lympho%
# 31     MONO        x10*9/l  0.59           91             monocytes
# 32      EOS        x10*9/l  0.17           92           eosinophils
# 33     BASO        x10*9/l  0.04           93             basophils
# 34    NRBCs           /100  <1.0           94                  nrbc
# 35     PLAT        x10*9/l   261           95             platelets
# 36      ESR           mm/h     1           96                   esr
# 37      TSH         milu/l  2.99          105                   tsh
# 38     vitD         nmol/l    83          110            vitamin d2
# 39     GALT         nmol/l    29          114       galt deficiency
# 40   PHEALA         nmol/l    20          117             phe level
# 41     URIC         mmol/l  0.21          283                 urate
# 42      PTH         pmol/l   3.5          300   parathyroid hormone
#
#                                                  text
# 0                          erythrocytes h 14 x10*6/l
# 1                               rubella igg  11 iu/ml
# 2                    sodium 140 l 134 139 140 mmol/l
# 3                   potassium 4.9 5.5 4.8 4.5 mmol/l
# 4                    chloride 106 106 107 106 mmol/l
# 5                     bicarbonate 23 21 21 25 mmol/l
# 6                        urea 4.0 4.8 5.3 5.1 mmol/l
# 7                      creatinine 70 70 65 65 umol/l
# 8                 egfr >90 >90 >90 >90 ml/min/1.73m2
# 9                                calcium 2.40 mmol/l
# 10                            phosphate. 1.08 mmol/l
# 11                    bili.total 11 h 20 h 18 umol/l
# 12                                  alp 59 60 70 u/l
# 13                                  ggt 13 11 15 u/l
# 14                                  ast 19 25 23 u/l
# 15                                  alt 16 12 22 u/l
# 16                        total protein 76 70 72 g/l
# 17                              albumin 46 44 46 g/l
# 18                          triglycerides 0.6 mmol/l
# 19                      f gluc plasma 4.5 4.7 mmol/l
# 20  diabetes is unlikely if fasting glucose levels...
# 21                       transferrin 2.2 2.5 2.7 g/l
# 22                        ferritin 38 719 39 47 ug/l
# 23                          hdl chol. 1.6 2.0 mmol/l
# 24                        hdl cholesterol >1.0 mmol/l
# 25                   non-hdl cholesterol <3.3 mmol/l
# 26                   haemoglobin 124 128 127 134 g/l
# 27                          mchc 328 338 344 325 g/l
# 28                       wcc 7.7 8.4 9.3 7.9 x10*9/l
# 29           neutrophils 4.32 4.50 4.69 4.11 x10*9/l
# 30           lymphocytes 2.77 2.96 3.67 2.96 x10*9/l
# 31             monocytes 0.52 0.76 0.63 0.59 x10*9/l
# 32           eosinophils 0.07 0.11 0.22 0.17 x10*9/l
# 33             basophils 0.04 0.07 0.04 0.04 x10*9/l
# 34                 nrbc <1.0 <1.0 <1.0 <1.0 /100 wbc
# 35                 platelets 221 267 234 261 x10*9/l
# 36                                        esr 1 mm/h
# 37                    tsh 1.14 1.18 1.57 2.99 milu/l
# 38                            vitamin d 73 83 nmol/l
# 39               moderate deficiency 12.5 - 29 nmol/l
# 40  winter - the level may need to be 10 - 20 nmol...
# 41                            urate 0.20 0.21 mmol/l
# 42             intact parathyroid hormone 3.5 pmol/l

# %% [markdown]
# - Both C02 and HCO3 have the synonym bicarbonate in X1 json (likely shouldn't be a sysnonym for CO2)
